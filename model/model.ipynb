# %% [markdown]
# importing libraries  in the model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import pipeline as pl
import sys
import  requests

# %% [markdown]
# importing dependencies in the model

# %%
# %pip install paddlepaddle
# %pip install paddleocr
# %pip install ollama
# %pip install paddlepaddle-gpu

# %% [markdown]
# pulling ollama into the system
#
# also download ollama from the web - https://ollama.com/download/windows
#
# after downloading ollama , go to terminal and write - ollama pull mistral
#
# this will download the model locally in your system
#
# after downloading it
#
# go to cmd again and do ollama run mistral
#
# host adress where llama is running is -127.0.0.1:11434

# %%
# !ollama pull mistral

# %% [markdown]
# running ollama
